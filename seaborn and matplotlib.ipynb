# %%
#importing packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris = pd.read_csv('~/Downloads/iris.csv', header='infer', sep=',')

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
spec = iris.groupby('species')
spec

# %% [markdown]
# ### A DataFrameGroupBy object represents the result of splitting a DataFrame into groups based on a specified column or columns. It acts as an intermediate object that allows you to perform aggregation, transformation, or filtration on the grouped data.

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
spec.describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %% [markdown]
# ### Benefits of combining groupby and describe
#
# Provides detailed statistics for each group, Useful for comparing distributions across categories, Identifies variability and central tendencies in grouped data.

# %%
versicolor = iris[iris['species'] == 'versicolor'].reset_index(drop=True)
setosa = iris[iris['species'] == 'setosa'].reset_index(drop=True)
virginica = iris[iris['species'] == 'virginica'].reset_index(drop=True)

sepal = iris[['sepal_length', 'sepal_width', 'species']]
petal = iris[['petal_length', 'petal_width', 'species']]

print("Setosa DataFrame:\n", setosa.head())
print("Versicolor DataFrame:\n", versicolor.head())
print("Virginica DataFrame:\n", virginica.head())
print("Sepal DataFrame:\n", sepal.head())
print("Petal DataFrame:\n", petal.head())
# Out:
# Setosa DataFrame:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Versicolor DataFrame:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0           7.0          3.2           4.7          1.4  versicolor
# 1           6.4          3.2           4.5          1.5  versicolor
# 2           6.9          3.1           4.9          1.5  versicolor
# 3           5.5          2.3           4.0          1.3  versicolor
# 4           6.5          2.8           4.6          1.5  versicolor
# Virginica DataFrame:
#     sepal_length  sepal_width  petal_length  petal_width    species
# ...

# %% [markdown]
# #### pd.concat is used to concatenate or merge the separated DataFrames back together

# %%
pd.concat([versicolor, setosa, virginica], axis=0)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            7.0          3.2           4.7          1.4  versicolor
# 1            6.4          3.2           4.5          1.5  versicolor
# 2            6.9          3.1           4.9          1.5  versicolor
# 3            5.5          2.3           4.0          1.3  versicolor
# 4            6.5          2.8           4.6          1.5  versicolor
# ..           ...          ...           ...          ...         ...
# 45           6.7          3.0           5.2          2.3   virginica
# 46           6.3          2.5           5.0          1.9   virginica
# 47           6.5          3.0           5.2          2.0   virginica
# 48           6.2          3.4           5.4          2.3   virginica
# 49           5.9          3.0           5.1          1.8   virginica
#
# [150 rows x 5 columns]

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ### **Wide Format**
# In the **wide format**, each row represents a single observation, and each variable is spread across multiple columns. This format is useful for easily comparing different variables for each observation.
#
# To convert from long to wide, use `pivot()` or `pivot_table()` in pandas.

# %% [markdown]
# ### **Long Format**
# In the **long format**, each row represents a single observation-variable pair, with a new column holding the value. This format is typically used for easier data manipulation, statistical analysis, and visualisations.
#
# To convert from wide to long, use `melt()` in pandas.

# %%
#long to wide format
flights_wide = flights.pivot(index='year', columns='month', values='passengers')
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %% [markdown]
# ## Titanic task

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Remove duplicate rows
titanic = titanic.drop_duplicates()
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  28.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
# ...

# %%
titanic['age'].fillna(titanic['age'].median(), inplace=True)
titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace=True)
titanic['fare'].fillna(titanic['fare'].median(), inplace=True)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  fare percentage
# 0    man        True  NaN  Southampton    no  False         0.025267
# 1  woman       False    C    Cherbourg   yes  False         0.248426
# 2  woman       False  NaN  Southampton   yes   True         0.027619
# 3  woman       False    C  Southampton   yes  False         0.185056
# 4    man        True  NaN  Southampton    no   True         0.028055

# %%
#average fare and age for each class
average_class = titanic.groupby('pclass')[['fare', 'age']].mean()
average_class
# Out:
#              fare        age
# pclass
# 1       84.487812  36.913178
# 2       21.835404  29.829273
# 3       13.574326  25.657139

# %%
#new column added showing the fare as a percentage of total
total_fare = titanic['fare'].sum()
titanic['fare percentage'] = (titanic['fare'] / (total_fare)) * 100
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  fare percentage
# 0    man        True  NaN  Southampton    no  False         0.026713
# 1  woman       False    C    Cherbourg   yes  False         0.262649
# 2  woman       False  NaN  Southampton   yes   True         0.029200
# 3  woman       False    C  Southampton   yes  False         0.195651
# 4    man        True  NaN  Southampton    no   True         0.029661

# %%
# how many survivors were female compared to male
gender_survival = titanic.groupby('sex')['survived'].sum()
gender_survival
# Out:
# sex
# female    217
# male      106
# Name: survived, dtype: int64

# %% [markdown]
# # Seaborn and Matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint', y='signal', data=fmri)
# Out:
# C:\Users\msb_0\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\msb_0\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
plt.plot(fmri.timepoint, fmri.signal)
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# C:\Users\msb_0\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# this shows the max values
plt.bar(tips.day, tips.total_bill)
# Out:
# <BarContainer object of 244 artists>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species')
# Out:
# C:\Users\msb_0\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\msb_0\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\msb_0\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_wide = flights.pivot(index='year', columns='month', values='passengers')
flights_wide
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights_wide)
# Out:
# <Axes: xlabel='month', ylabel='year'>
